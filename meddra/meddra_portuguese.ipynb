# %% [markdown]
# ## Meddra files parser
#
# 1. System Organ Class (i.e. Gastrointestinal disorders)
# 2. High Level Group Term (i.e. Gastrointestinal signs and symptoms)
# 3. High Level Term (i.e. Nausea and vomiting symptoms)
# 4. Prefered Term (i.e Nausea)
# 5. Lowest Level Term (i.e Feeling queasy)
#
# Nome do ficheiro1 hlgt.asc
# hlgt_hlt.asc
# hlt.asc
# hlt_pt.asc
# llt.asc meddra_history_portuguese.asc meddra_release.asc
# mdhier.asc pt.asc
# soc.asc soc_hlgt.asc intl_ord.asc smq_list.asc smq_content.asc
# Tabela do MedDRA
# 1_hlgt_pref_term 1_hlgt_hlt_comp 1_hlt_pref_term 1_hlt_pref_comp 1_low_level_term N/A*
# N/A 1_md_hierarchy 1_pref_term 1_soc_term 1_soc_hlgt_comp 1_soc_intl_order 1_smq_list 1_smq_content

# %%
import pandas as pd

# %%
hlgt_hlt_cols=["Hlgt_code","hlt_code"]
hlgt_cols=["hlgt_code","hlgt_name","hlgt_whoart_code","hlgt_harts_code","hlgt_costart_sym","hlgt_icd9_code","hlgt_icd9cm_code","hlgt_icd10_code","hlgt_jart_code"]
hlt_pt_cols=["hlt_code","pt_code"]
hlt_cols=["hlt_code","hlt_name","hlt_whoart_code","hlt_harts_code","hlt_costart_sym","hlt_icd9_code","hlt_icd9cm_code","hlt_icd10_code","hlt_jart_code"]
llt_cols=["llt_code","llt_name","pt_code","llt_whoart_code","llt_harts_code","llt_costart_sym","llt_icd9_code","llt_icd9cm_code","llt_icd10_code","llt_currency","llt_jart_code"]
mdhier_cols=["pt_code","hlt_code","hglt_code","soc_code","pt_name","hlt_name","hglt_name","soc_name","soc_abbrev","null_field","pt_soc_code","primary_soc_fg"]
pt_cols=["pt_code","pt_name","null_field","pt_soc_code","pt_whoart_code","pt_harts_code","pt_costart_sym","pt_icd9_code","pt_icd9cm_code","pt_icd10_code","pt_jart_code"]
soc_hlgt_cols=["soc_code","hlgt_code"]
intl_ord_cols=["intl_ord_code","soc_code"]

# %%
hlgt_hlt=pd.read_table("/Users/joaoalmeida/Downloads/MedDRA_25_1_Portuguese/ascii-251/hlgt_hlt.asc", sep="$", header=None,encoding='ascii')
hlgt=pd.read_table("/Users/joaoalmeida/Downloads/MedDRA_25_1_Portuguese/ascii-251/hlgt.asc", sep="$", header=None,encoding='latin-1')
hlt_pt=pd.read_table("/Users/joaoalmeida/Downloads/MedDRA_25_1_Portuguese/ascii-251/hlt_pt.asc", sep="$", header=None,encoding='latin-1')
hlt=pd.read_table("/Users/joaoalmeida/Downloads/MedDRA_25_1_Portuguese/ascii-251/hlt.asc", sep="$", header=None,encoding='latin-1')
intl_ord=pd.read_table("/Users/joaoalmeida/Downloads/MedDRA_25_1_Portuguese/ascii-251/intl_ord.asc", sep="$", header=None,encoding='latin-1')
llt=pd.read_table("/Users/joaoalmeida/Downloads/MedDRA_25_1_Portuguese/ascii-251/llt.asc", sep="$", header=None,encoding='latin-1')
mdhier=pd.read_table("/Users/joaoalmeida/Downloads/MedDRA_25_1_Portuguese/ascii-251/mdhier.asc", sep="$", header=None,encoding='latin-1')
pt=pd.read_table("/Users/joaoalmeida/Downloads/MedDRA_25_1_Portuguese/ascii-251/pt.asc", sep="$", header=None,encoding='latin-1')
soc_hlgt=pd.read_table("/Users/joaoalmeida/Downloads/MedDRA_25_1_Portuguese/ascii-251/soc_hlgt.asc", sep="$", header=None,encoding='latin-1')

# %%
hlgt_hlt = hlgt_hlt.iloc[: , :-1]
hlgt=hlgt.iloc[: , :-1]
hlt_pt=hlt_pt.iloc[: , :-1]
hlt=hlt.iloc[: , :-1]
llt=llt.iloc[: , :-1]
mdhier=mdhier.iloc[: , :-1]
pt=pt.iloc[: , :-1]
soc_hlgt=soc_hlgt.iloc[: , :-1]
intl_ord=intl_ord.iloc[: , :-1]

# %%
hlgt_hlt.columns=hlgt_hlt_cols
hlgt.columns=hlgt_cols
hlt_pt.columns=hlt_pt_cols
hlt.columns=hlt_cols
llt.columns=llt_cols
mdhier.columns=mdhier_cols
pt.columns=pt_cols
soc_hlgt.columns=soc_hlgt_cols
intl_ord.columns=intl_ord_cols

# %%
pt
# Out:
#         pt_code                                 pt_name  null_field  \
# 0      10000002      Deficiência de 11-beta-hidroxilase         NaN
# 1      10000005               17-cetosteróides na urina         NaN
# 2      10000007    17-cetosteróides na urina diminuídos         NaN
# 3      10000009    17-cetosteróides na urina aumentados         NaN
# 4      10000011       17-cetosteróides na urina normais         NaN
# ...         ...                                     ...         ...
# 25587  10087968            Trombose da veia espermática         NaN
# 25588  10087973                       Gangrena pulmonar         NaN
# 25589  10087974  Extravasão no local de acesso vascular         NaN
# 25590  10087975                 Necrose retroperitoneal         NaN
# 25591  10087980           Triptassemia alfa hereditária         NaN
#
#        pt_soc_code  pt_whoart_code  pt_harts_code  pt_costart_sym  \
# 0         10010331             NaN            NaN             NaN
# 1         10022891             NaN            NaN             NaN
# 2         10022891             NaN            NaN             NaN
# 3         10022891             NaN            NaN             NaN
# 4         10022891             NaN            NaN             NaN
# ...            ...             ...            ...             ...
# 25587     10038604             NaN            NaN             NaN
# 25588     10021881             NaN            NaN             NaN
# 25589     10022117             NaN            NaN             NaN
# 25590     10017947             NaN            NaN             NaN
# 25591     10010331             NaN            NaN             NaN
#
#        pt_icd9_code  pt_icd9cm_code  pt_icd10_code  pt_jart_code
# 0               NaN             NaN            NaN           NaN
# 1               NaN             NaN            NaN           NaN
# 2               NaN             NaN            NaN           NaN
# 3               NaN             NaN            NaN           NaN
# 4               NaN             NaN            NaN           NaN
# ...             ...             ...            ...           ...
# 25587           NaN             NaN            NaN           NaN
# 25588           NaN             NaN            NaN           NaN
# 25589           NaN             NaN            NaN           NaN
# 25590           NaN             NaN            NaN           NaN
# 25591           NaN             NaN            NaN           NaN
#
# [25592 rows x 11 columns]

# %%
llt[llt["pt_code"]==10000002]
# Out:
#    llt_code                            llt_name   pt_code  llt_whoart_code  \
# 1  10000002  Deficiência de 11-beta-hidroxilase  10000002              NaN
#
#    llt_harts_code  llt_costart_sym  llt_icd9_code  llt_icd9cm_code  \
# 1             NaN              NaN            NaN              NaN
#
#    llt_icd10_code llt_currency  llt_jart_code
# 1             NaN            Y            NaN

# %%
import sqlalchemy
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 import sqlalchemy
#
# ModuleNotFoundError: No module named 'sqlalchemy'

# %%
SQLALCHEMY_DATABASE_URI = "mysql+pymysql://api:ZSCO1wtnkwU9fBsa5/fS@127.0.0.1:3306/repository"
# Test if it works
engine = sqlalchemy.create_engine(SQLALCHEMY_DATABASE_URI, echo=False)
conn=engine.connect()

# %%
pt.to_sql("meddra_prefered_term_pt", con=conn, if_exists="replace", index=False)
llt.to_sql("meddra_low_level_term_pt", con=conn, if_exists="replace", index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 pt.to_sql("meddra_prefered_term_pt", con=conn, if_exists="replace", index=False)
#       2 llt.to_sql("meddra_low_level_term_pt", con=conn, if_exists="replace", index=False)
#
# NameError: name 'conn' is not defined

# %%
pt.to_csv("meddra_prefered_term_pt.csv", index=False)
llt.to_csv("meddra_low_level_term_pt.csv", index=False)

# %%
llt_en=pd.read_table("/Users/joaoalmeida/Downloads/MedDRA_25_1_English/MedAscii/llt.asc", sep="$", header=None,encoding='latin-1')
pt_en=pd.read_table("/Users/joaoalmeida/Downloads/MedDRA_25_1_English/MedAscii/pt.asc", sep="$", header=None,encoding='latin-1')

# %%
llt_en=llt_en.iloc[: , :-1]
pt_en=pt_en.iloc[: , :-1]

# %%
llt_en.columns=llt_cols
pt_en.columns=pt_cols

# %%
pt_en.to_sql("meddra_prefered_term_en", con=conn, if_exists="replace", index=False)
llt_en.to_sql("meddra_low_level_term_en", con=conn, if_exists="replace", index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 pt_en.to_sql("meddra_prefered_term_en", con=conn, if_exists="replace", index=False)
#       2 llt_en.to_sql("meddra_low_level_term_en", con=conn, if_exists="replace", index=False)
#
# NameError: name 'conn' is not defined

# %%
pt_en.to_csv("meddra_prefered_term_en.csv", index=False)
llt_en.to_csv("meddra_low_level_term_en.csv", index=False)

# %%
pt_en
# Out:
#         pt_code                             pt_name  null_field  pt_soc_code  \
# 0      10000002      11-beta-hydroxylase deficiency         NaN     10010331
# 1      10000005               17 ketosteroids urine         NaN     10022891
# 2      10000007     17 ketosteroids urine decreased         NaN     10022891
# 3      10000009     17 ketosteroids urine increased         NaN     10022891
# 4      10000011        17 ketosteroids urine normal         NaN     10022891
# ...         ...                                 ...         ...          ...
# 25587  10087968           Spermatic vein thrombosis         NaN     10038604
# 25588  10087973                  Pulmonary gangrene         NaN     10021881
# 25589  10087974  Vascular access site extravasation         NaN     10022117
# 25590  10087975            Retroperitoneal necrosis         NaN     10017947
# 25591  10087980       Hereditary alpha tryptasaemia         NaN     10010331
#
#        pt_whoart_code  pt_harts_code  pt_costart_sym  pt_icd9_code  \
# 0                 NaN            NaN             NaN           NaN
# 1                 NaN            NaN             NaN           NaN
# 2                 NaN            NaN             NaN           NaN
# 3                 NaN            NaN             NaN           NaN
# 4                 NaN            NaN             NaN           NaN
# ...               ...            ...             ...           ...
# 25587             NaN            NaN             NaN           NaN
# 25588             NaN            NaN             NaN           NaN
# 25589             NaN            NaN             NaN           NaN
# 25590             NaN            NaN             NaN           NaN
# 25591             NaN            NaN             NaN           NaN
#
#        pt_icd9cm_code  pt_icd10_code  pt_jart_code
# 0                 NaN            NaN           NaN
# 1                 NaN            NaN           NaN
# 2                 NaN            NaN           NaN
# 3                 NaN            NaN           NaN
# 4                 NaN            NaN           NaN
# ...               ...            ...           ...
# 25587             NaN            NaN           NaN
# 25588             NaN            NaN           NaN
# 25589             NaN            NaN           NaN
# 25590             NaN            NaN           NaN
# 25591             NaN            NaN           NaN
#
# [25592 rows x 11 columns]

# %%
pt_en
# Out:
#         pt_code                             pt_name  null_field  pt_soc_code  \
# 0      10000002      11-beta-hydroxylase deficiency         NaN     10010331
# 1      10000005               17 ketosteroids urine         NaN     10022891
# 2      10000007     17 ketosteroids urine decreased         NaN     10022891
# 3      10000009     17 ketosteroids urine increased         NaN     10022891
# 4      10000011        17 ketosteroids urine normal         NaN     10022891
# ...         ...                                 ...         ...          ...
# 25587  10087968           Spermatic vein thrombosis         NaN     10038604
# 25588  10087973                  Pulmonary gangrene         NaN     10021881
# 25589  10087974  Vascular access site extravasation         NaN     10022117
# 25590  10087975            Retroperitoneal necrosis         NaN     10017947
# 25591  10087980       Hereditary alpha tryptasaemia         NaN     10010331
#
#        pt_whoart_code  pt_harts_code  pt_costart_sym  pt_icd9_code  \
# 0                 NaN            NaN             NaN           NaN
# 1                 NaN            NaN             NaN           NaN
# 2                 NaN            NaN             NaN           NaN
# 3                 NaN            NaN             NaN           NaN
# 4                 NaN            NaN             NaN           NaN
# ...               ...            ...             ...           ...
# 25587             NaN            NaN             NaN           NaN
# 25588             NaN            NaN             NaN           NaN
# 25589             NaN            NaN             NaN           NaN
# 25590             NaN            NaN             NaN           NaN
# 25591             NaN            NaN             NaN           NaN
#
#        pt_icd9cm_code  pt_icd10_code  pt_jart_code
# 0                 NaN            NaN           NaN
# 1                 NaN            NaN           NaN
# 2                 NaN            NaN           NaN
# 3                 NaN            NaN           NaN
# 4                 NaN            NaN           NaN
# ...               ...            ...           ...
# 25587             NaN            NaN           NaN
# 25588             NaN            NaN           NaN
# 25589             NaN            NaN           NaN
# 25590             NaN            NaN           NaN
# 25591             NaN            NaN           NaN
#
# [25592 rows x 11 columns]

# %%
llt_en
# Out:
#        llt_code                           llt_name   pt_code  llt_whoart_code  \
# 0      10000001            Ventilation pneumonitis  10081988              NaN
# 1      10000002     11-beta-hydroxylase deficiency  10000002              NaN
# 2      10000003        11-oxysteroid activity incr  10033315              NaN
# 3      10000004   11-oxysteroid activity increased  10033315              NaN
# 4      10000005              17 ketosteroids urine  10000005              NaN
# ...         ...                                ...       ...              ...
# 85663  10087977             Infantile fibrosarcoma  10065859              NaN
# 85664  10087978  Hormone-sensitive prostate cancer  10071119              NaN
# 85665  10087979              Retinal atrophic hole  10038897              NaN
# 85666  10087980      Hereditary alpha tryptasaemia  10087980              NaN
# 85667  10087981       Hereditary alpha tryptasemia  10087980              NaN
#
#        llt_harts_code  llt_costart_sym  llt_icd9_code  llt_icd9cm_code  \
# 0                 NaN              NaN            NaN              NaN
# 1                 NaN              NaN            NaN              NaN
# 2                 NaN              NaN            NaN              NaN
# 3                 NaN              NaN            NaN              NaN
# 4                 NaN              NaN            NaN              NaN
# ...               ...              ...            ...              ...
# 85663             NaN              NaN            NaN              NaN
# 85664             NaN              NaN            NaN              NaN
# 85665             NaN              NaN            NaN              NaN
# 85666             NaN              NaN            NaN              NaN
# 85667             NaN              NaN            NaN              NaN
#
#        llt_icd10_code llt_currency  llt_jart_code
# 0                 NaN            N            NaN
# 1                 NaN            Y            NaN
# 2                 NaN            N            NaN
# 3                 NaN            Y            NaN
# 4                 NaN            Y            NaN
# ...               ...          ...            ...
# 85663             NaN            Y            NaN
# 85664             NaN            Y            NaN
# 85665             NaN            Y            NaN
# 85666             NaN            Y            NaN
# 85667             NaN            Y            NaN
#
# [85668 rows x 11 columns]

# %%
pt_llt_en=pd.merge(pt_en,llt_en,on="pt_code")
pt_llt_en
# Out:
#         pt_code                             pt_name  null_field  pt_soc_code  \
# 0      10000002      11-beta-hydroxylase deficiency         NaN     10010331
# 1      10000005               17 ketosteroids urine         NaN     10022891
# 2      10000007     17 ketosteroids urine decreased         NaN     10022891
# 3      10000007     17 ketosteroids urine decreased         NaN     10022891
# 4      10000009     17 ketosteroids urine increased         NaN     10022891
# ...         ...                                 ...         ...          ...
# 85663  10087973                  Pulmonary gangrene         NaN     10021881
# 85664  10087974  Vascular access site extravasation         NaN     10022117
# 85665  10087975            Retroperitoneal necrosis         NaN     10017947
# 85666  10087980       Hereditary alpha tryptasaemia         NaN     10010331
# 85667  10087980       Hereditary alpha tryptasaemia         NaN     10010331
#
#        pt_whoart_code  pt_harts_code  pt_costart_sym  pt_icd9_code  \
# 0                 NaN            NaN             NaN           NaN
# 1                 NaN            NaN             NaN           NaN
# 2                 NaN            NaN             NaN           NaN
# 3                 NaN            NaN             NaN           NaN
# 4                 NaN            NaN             NaN           NaN
# ...               ...            ...             ...           ...
# 85663             NaN            NaN             NaN           NaN
# 85664             NaN            NaN             NaN           NaN
# 85665             NaN            NaN             NaN           NaN
# 85666             NaN            NaN             NaN           NaN
# 85667             NaN            NaN             NaN           NaN
#
#        pt_icd9cm_code  pt_icd10_code  ...  llt_code  \
# 0                 NaN            NaN  ...  10000002
# 1                 NaN            NaN  ...  10000005
# 2                 NaN            NaN  ...  10000007
# 3                 NaN            NaN  ...  10000010
# 4                 NaN            NaN  ...  10000008
# ...               ...            ...  ...       ...
# 85663             NaN            NaN  ...  10087973
# 85664             NaN            NaN  ...  10087974
# 85665             NaN            NaN  ...  10087975
# 85666             NaN            NaN  ...  10087980
# 85667             NaN            NaN  ...  10087981
#
#                                  llt_name llt_whoart_code  llt_harts_code  \
# 0          11-beta-hydroxylase deficiency             NaN             NaN
# 1                   17 ketosteroids urine             NaN             NaN
# 2         17 ketosteroids urine decreased             NaN             NaN
# 3               17 ketosteroids urine low             NaN             NaN
# 4              17 ketosteroids urine high             NaN             NaN
# ...                                   ...             ...             ...
# 85663                  Pulmonary gangrene             NaN             NaN
# 85664  Vascular access site extravasation             NaN             NaN
# 85665            Retroperitoneal necrosis             NaN             NaN
# 85666       Hereditary alpha tryptasaemia             NaN             NaN
# 85667        Hereditary alpha tryptasemia             NaN             NaN
#
#        llt_costart_sym  llt_icd9_code  llt_icd9cm_code  llt_icd10_code  \
# 0                  NaN            NaN              NaN             NaN
# 1                  NaN            NaN              NaN             NaN
# 2                  NaN            NaN              NaN             NaN
# 3                  NaN            NaN              NaN             NaN
# 4                  NaN            NaN              NaN             NaN
# ...                ...            ...              ...             ...
# 85663              NaN            NaN              NaN             NaN
# 85664              NaN            NaN              NaN             NaN
# 85665              NaN            NaN              NaN             NaN
# 85666              NaN            NaN              NaN             NaN
# 85667              NaN            NaN              NaN             NaN
#
#        llt_currency llt_jart_code
# 0                 Y           NaN
# 1                 Y           NaN
# 2                 Y           NaN
# 3                 Y           NaN
# 4                 Y           NaN
# ...             ...           ...
# 85663             Y           NaN
# 85664             Y           NaN
# 85665             Y           NaN
# 85666             Y           NaN
# 85667             Y           NaN
#
# [85668 rows x 21 columns]

# %%
soc_en=pd.read_table("/Users/joaoalmeida/Downloads/MedDRA_25_1_English/MedAscii/soc.asc", sep="$", header=None,encoding='latin-1')
soc_en.columns=["soc_ code", "soc_name", "soc_abbrev", "soc_whoart_code+", "soc_harts_code+", "soc_costart_sym+", "soc_icd9_code+", "soc_icd9cm_code+", "soc_icd10_code+", "soc_jart_code+","??"]

# %%
soc_en
# Out:
#     soc_ code                                           soc_name soc_abbrev  \
# 0    10005329               Blood and lymphatic system disorders      Blood
# 1    10007541                                  Cardiac disorders       Card
# 2    10010331         Congenital, familial and genetic disorders       Cong
# 3    10013993                        Ear and labyrinth disorders        Ear
# 4    10014698                                Endocrine disorders       Endo
# 5    10015919                                      Eye disorders        Eye
# 6    10017947                         Gastrointestinal disorders      Gastr
# 7    10018065  General disorders and administration site cond...      Genrl
# 8    10019805                            Hepatobiliary disorders      Hepat
# 9    10021428                            Immune system disorders      Immun
# 10   10021881                        Infections and infestations      Infec
# 11   10022117     Injury, poisoning and procedural complications      Inj&P
# 12   10022891                                     Investigations        Inv
# 13   10027433                 Metabolism and nutrition disorders      Metab
# 14   10028395    Musculoskeletal and connective tissue disorders       Musc
# 15   10029104  Neoplasms benign, malignant and unspecified (i...      Neopl
# 16   10029205                           Nervous system disorders       Nerv
# 17   10036585     Pregnancy, puerperium and perinatal conditions       Preg
# 18   10037175                              Psychiatric disorders      Psych
# 19   10038359                        Renal and urinary disorders      Renal
# 20   10038604           Reproductive system and breast disorders      Repro
# 21   10038738    Respiratory, thoracic and mediastinal disorders       Resp
# 22   10040785             Skin and subcutaneous tissue disorders       Skin
# 23   10041244                               Social circumstances      SocCi
# 24   10042613                    Surgical and medical procedures       Surg
# 25   10047065                                 Vascular disorders       Vasc
# 26   10077536                                     Product issues       Prod
#
#     soc_whoart_code+  soc_harts_code+  soc_costart_sym+  soc_icd9_code+  \
# 0                NaN              NaN               NaN             NaN
# 1                NaN              NaN               NaN             NaN
# 2                NaN              NaN               NaN             NaN
# 3                NaN              NaN               NaN             NaN
# 4                NaN              NaN               NaN             NaN
# 5                NaN              NaN               NaN             NaN
# 6                NaN              NaN               NaN             NaN
# 7                NaN              NaN               NaN             NaN
# 8                NaN              NaN               NaN             NaN
# 9                NaN              NaN               NaN             NaN
# 10               NaN              NaN               NaN             NaN
# 11               NaN              NaN               NaN             NaN
# 12               NaN              NaN               NaN             NaN
# 13               NaN              NaN               NaN             NaN
# 14               NaN              NaN               NaN             NaN
# 15               NaN              NaN               NaN             NaN
# 16               NaN              NaN               NaN             NaN
# 17               NaN              NaN               NaN             NaN
# 18               NaN              NaN               NaN             NaN
# 19               NaN              NaN               NaN             NaN
# 20               NaN              NaN               NaN             NaN
# 21               NaN              NaN               NaN             NaN
# 22               NaN              NaN               NaN             NaN
# 23               NaN              NaN               NaN             NaN
# 24               NaN              NaN               NaN             NaN
# 25               NaN              NaN               NaN             NaN
# 26               NaN              NaN               NaN             NaN
#
#     soc_icd9cm_code+  soc_icd10_code+  soc_jart_code+  ??
# 0                NaN              NaN             NaN NaN
# 1                NaN              NaN             NaN NaN
# 2                NaN              NaN             NaN NaN
# 3                NaN              NaN             NaN NaN
# 4                NaN              NaN             NaN NaN
# 5                NaN              NaN             NaN NaN
# 6                NaN              NaN             NaN NaN
# 7                NaN              NaN             NaN NaN
# 8                NaN              NaN             NaN NaN
# 9                NaN              NaN             NaN NaN
# 10               NaN              NaN             NaN NaN
# 11               NaN              NaN             NaN NaN
# 12               NaN              NaN             NaN NaN
# 13               NaN              NaN             NaN NaN
# 14               NaN              NaN             NaN NaN
# 15               NaN              NaN             NaN NaN
# 16               NaN              NaN             NaN NaN
# 17               NaN              NaN             NaN NaN
# 18               NaN              NaN             NaN NaN
# 19               NaN              NaN             NaN NaN
# 20               NaN              NaN             NaN NaN
# 21               NaN              NaN             NaN NaN
# 22               NaN              NaN             NaN NaN
# 23               NaN              NaN             NaN NaN
# 24               NaN              NaN             NaN NaN
# 25               NaN              NaN             NaN NaN
# 26               NaN              NaN             NaN NaN

# %%
soc_hlgt=pd.read_table("/Users/joaoalmeida/Downloads/MedDRA_25_1_English/MedAscii/soc_hlgt.asc", sep="$", header=None,encoding='ascii')
soc_hlgt.columns=["soc_code","hlgt_code","??"]
soc_hlgt
# Out:
#      soc_code  hlgt_code  ??
# 0    10005329   10002086 NaN
# 1    10005329   10018849 NaN
# 2    10005329   10018865 NaN
# 3    10005329   10018902 NaN
# 4    10005329   10018911 NaN
# ..        ...        ...  ..
# 349  10047065   10057165 NaN
# 350  10047065   10057166 NaN
# 351  10047065   10082207 NaN
# 352  10077536   10069782 NaN
# 353  10077536   10077537 NaN
#
# [354 rows x 3 columns]

# %%
mdhier=pd.read_table("/Users/joaoalmeida/Downloads/MedDRA_25_1_English/MedAscii/mdhier.asc", sep="$", header=None,encoding='ascii')
mdhier.columns=["pt_code",
"hlt_code",
"hlgt_code",
"soc_code",
"pt_name",
"hlt_name",
"hlgt_name",
"soc_name",
"soc_abbrev",
"null_field",
"pt_soc_code",
"primary_soc_fg","??"]
mdhier
# Out:
#         pt_code  hlt_code  hlgt_code  soc_code  \
# 0      10002043  10002042   10002086  10005329
# 1      10002080  10002042   10002086  10005329
# 2      10002081  10002042   10002086  10005329
# 3      10022972  10002042   10002086  10005329
# 4      10034695  10002042   10002086  10005329
# ...         ...       ...        ...       ...
# 39642  10079432  10077544   10077537  10077536
# 39643  10083571  10077544   10077537  10077536
# 39644  10077800  10077545   10077537  10077536
# 39645  10077801  10077545   10077537  10077536
# 39646  10080231  10077545   10077537  10077536
#
#                                     pt_name  \
# 0                 Anaemia folate deficiency
# 1            Anaemia vitamin B12 deficiency
# 2             Anaemia vitamin B6 deficiency
# 3                   Iron deficiency anaemia
# 4                        Pernicious anaemia
# ...                                     ...
# 39642  Manufacturing product shipping issue
# 39643   Product temperature excursion issue
# 39644            Product availability issue
# 39645                  Product supply issue
# 39646                      Recalled product
#
#                                       hlt_name  \
# 0                         Anaemia deficiencies
# 1                         Anaemia deficiencies
# 2                         Anaemia deficiencies
# 3                         Anaemia deficiencies
# 4                         Anaemia deficiencies
# ...                                        ...
# 39642  Product distribution and storage issues
# 39643  Product distribution and storage issues
# 39644   Product supply and availability issues
# 39645   Product supply and availability issues
# 39646   Product supply and availability issues
#
#                                                hlgt_name  \
# 0           Anaemias nonhaemolytic and marrow depression
# 1           Anaemias nonhaemolytic and marrow depression
# 2           Anaemias nonhaemolytic and marrow depression
# 3           Anaemias nonhaemolytic and marrow depression
# 4           Anaemias nonhaemolytic and marrow depression
# ...                                                  ...
# 39642  Product quality, supply, distribution, manufac...
# 39643  Product quality, supply, distribution, manufac...
# 39644  Product quality, supply, distribution, manufac...
# 39645  Product quality, supply, distribution, manufac...
# 39646  Product quality, supply, distribution, manufac...
#
#                                    soc_name soc_abbrev  null_field  \
# 0      Blood and lymphatic system disorders      Blood         NaN
# 1      Blood and lymphatic system disorders      Blood         NaN
# 2      Blood and lymphatic system disorders      Blood         NaN
# 3      Blood and lymphatic system disorders      Blood         NaN
# 4      Blood and lymphatic system disorders      Blood         NaN
# ...                                     ...        ...         ...
# 39642                        Product issues       Prod         NaN
# 39643                        Product issues       Prod         NaN
# 39644                        Product issues       Prod         NaN
# 39645                        Product issues       Prod         NaN
# 39646                        Product issues       Prod         NaN
#
#        pt_soc_code primary_soc_fg  ??
# 0         10005329              Y NaN
# 1         10005329              Y NaN
# 2         10005329              Y NaN
# 3         10005329              Y NaN
# 4         10005329              Y NaN
# ...            ...            ...  ..
# 39642     10077536              Y NaN
# 39643     10077536              Y NaN
# 39644     10077536              Y NaN
# 39645     10077536              Y NaN
# 39646     10077536              Y NaN
#
# [39647 rows x 13 columns]

# %%
hlgt_hlt=pd.read_table("/Users/joaoalmeida/Downloads/MedDRA_25_1_English/MedAscii/hlgt_hlt.asc", sep="$", header=None,encoding='ascii')
hlgt_hlt.columns=["hlgt_code","hlt_code","?"]
hlgt_hlt
# Out:
#       hlgt_code  hlt_code   ?
# 0      10000073  10012714 NaN
# 1      10000073  10016435 NaN
# 2      10000073  10021620 NaN
# 3      10000073  10022017 NaN
# 4      10000073  10045459 NaN
# ...         ...       ...  ..
# 1750   10087059  10040787 NaN
# 1751   10087059  10040788 NaN
# 1752   10087059  10040791 NaN
# 1753   10087059  10040793 NaN
# 1754   10087059  10040797 NaN
#
# [1755 rows x 3 columns]

# %%
hlgt=pd.read_table("/Users/joaoalmeida/Downloads/MedDRA_25_1_English/MedAscii/hlgt.asc", sep="$", header=None,encoding='ascii')
hlgt.columns=["hlgt_code", "hlgt_name", "hlgt_whoart_code+", "hlgt_harts_code+", "hlgt_costart_sym+", "hlgt_icd9_code+", "hlgt_icd9cm_code+", "hlgt_icd10_code+", "hlgt_jart_code+","?"]
hlgt
# Out:
#      hlgt_code                                          hlgt_name  \
# 0     10000073  Abdominal hernias and other abdominal wall con...
# 1     10000211                           Abortions and stillbirth
# 2     10000485                                Acid-base disorders
# 3     10000546                           Metabolism disorders NEC
# 4     10001302               Adjustment disorders (incl subtypes)
# ..         ...                                                ...
# 332   10082206          Cardiac disorders, signs and symptoms NEC
# 333   10082207              Vascular infections and inflammations
# 334   10083624  Chromosomal abnormalities, gene alterations an...
# 335   10087058    Cytogenetic investigations and genetic analyses
# 336   10087059  Skin and subcutaneous tissue infections and in...
#
#      hlgt_whoart_code+  hlgt_harts_code+  hlgt_costart_sym+  hlgt_icd9_code+  \
# 0                  NaN               NaN                NaN              NaN
# 1                  NaN               NaN                NaN              NaN
# 2                  NaN               NaN                NaN              NaN
# 3                  NaN               NaN                NaN              NaN
# 4                  NaN               NaN                NaN              NaN
# ..                 ...               ...                ...              ...
# 332                NaN               NaN                NaN              NaN
# 333                NaN               NaN                NaN              NaN
# 334                NaN               NaN                NaN              NaN
# 335                NaN               NaN                NaN              NaN
# 336                NaN               NaN                NaN              NaN
#
#      hlgt_icd9cm_code+  hlgt_icd10_code+  hlgt_jart_code+   ?
# 0                  NaN               NaN              NaN NaN
# 1                  NaN               NaN              NaN NaN
# 2                  NaN               NaN              NaN NaN
# 3                  NaN               NaN              NaN NaN
# 4                  NaN               NaN              NaN NaN
# ..                 ...               ...              ...  ..
# 332                NaN               NaN              NaN NaN
# 333                NaN               NaN              NaN NaN
# 334                NaN               NaN              NaN NaN
# 335                NaN               NaN              NaN NaN
# 336                NaN               NaN              NaN NaN
#
# [337 rows x 10 columns]

# %%
hlt=pd.read_table("/Users/joaoalmeida/Downloads/MedDRA_25_1_English/MedAscii/hlt.asc", sep="$", header=None,encoding='ascii')
hlt.columns=["hlt_code", "hlt_name", "hlt_whoart_code+", "hlt_harts_code+", "hlt_costart_sym+", "hlt_icd9_code+", "hlt_icd9cm_code+", "hlt_icd10_code+", "hlt_jart_code+","?"]
hlt
# Out:
#       hlt_code                                         hlt_name  \
# 0     10000032                     Cardiac conduction disorders
# 1     10000063                      Abdominal findings abnormal
# 2     10000117                           Abnormal behaviour NEC
# 3     10000135                        Abnormal food elimination
# 4     10000171                                Abnormal reflexes
# ...        ...                                              ...
# 1732  10085260                       Hepatitis virus infections
# 1733  10085261    Auditory and vestibular diagnostic procedures
# 1734  10085262                             Follicular lymphomas
# 1735  10087056  Skin histopathology and skin investigations NEC
# 1736  10087057     Hepatobiliary function diagnostic procedures
#
#       hlt_whoart_code+  hlt_harts_code+  hlt_costart_sym+  hlt_icd9_code+  \
# 0                  NaN              NaN               NaN             NaN
# 1                  NaN              NaN               NaN             NaN
# 2                  NaN              NaN               NaN             NaN
# 3                  NaN              NaN               NaN             NaN
# 4                  NaN              NaN               NaN             NaN
# ...                ...              ...               ...             ...
# 1732               NaN              NaN               NaN             NaN
# 1733               NaN              NaN               NaN             NaN
# 1734               NaN              NaN               NaN             NaN
# 1735               NaN              NaN               NaN             NaN
# 1736               NaN              NaN               NaN             NaN
#
#       hlt_icd9cm_code+  hlt_icd10_code+  hlt_jart_code+   ?
# 0                  NaN              NaN             NaN NaN
# 1                  NaN              NaN             NaN NaN
# 2                  NaN              NaN             NaN NaN
# 3                  NaN              NaN             NaN NaN
# 4                  NaN              NaN             NaN NaN
# ...                ...              ...             ...  ..
# 1732               NaN              NaN             NaN NaN
# 1733               NaN              NaN             NaN NaN
# 1734               NaN              NaN             NaN NaN
# 1735               NaN              NaN             NaN NaN
# 1736               NaN              NaN             NaN NaN
#
# [1737 rows x 10 columns]

# %%
pt_llt_en.to_csv("pt_llt_en.csv")
